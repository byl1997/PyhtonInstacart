# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
path = r'C:\Users\byl19\Downloads\02-2023 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\byl19\Downloads\02-2023 Instacart Basket Analysis\02 Data\Prepared Data\opm.pkl')

# %%
ords_prods_merge['user_id'].dtype
# Out:
# dtype('O')

# %%
ords_prods_merge.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    -1.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices    price_range_loc    busiest days  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 22)

# %% [markdown]
# # 03. Exercise Questions

# %%
#2 
ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #3
# There is quite a difference when comparing the entire data set to just the subset. The main difference is in the subset there were many missing department id's while the entire data frame includes all 21 of them. When comparing the department id numbers in the subset to the entire there are also some slight differences like department 13 in the subset had a mean of 17.9 and in the entire its 16.5.

# %%
#4 loyalty flag transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#4 loyalty flag loc
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.lo`c[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New custsomer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New custsomer        6243990
# Name: loyalty_flag, dtype: int64

# %%
#5
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean','max','min']})
# Out:
#                      prices
#                        mean      max  min
# loyalty_flag
# Loyal customer    10.386336  99999.0  1.0
# New custsomer     13.294670  99999.0  1.0
# Regular customer  12.495717  99999.0  1.0

# %%
#6 spending flag transform
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#6 checking head
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
ords_prods_merge.drop(columns=['averge_price', 'averege_price'])
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                    -1.0         196
# 1                         7                    15.0         196
# ...

# %%
#6 spending flag loc
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
#6 check
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
#7 order frequncy flag transform
ords_prods_merge['median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#7 check
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
#7 order frequency loc
ords_prods_merge.loc[ords_prods_merge['median_days'] > 20, 'order_freq_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days'] > 10) & (ords_prods_merge['median_days'] <= 20), 'order_freq_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days'] <= 10, 'order_freq_flag'] = 'Frequent customer'

# %%
#7 check
ords_prods_merge[['user_id','order_freq_flag','median_days']].head(60)
# Out:
#     user_id        order_freq_flag  median_days
# 0         1       Regular customer         20.0
# 1         1       Regular customer         20.0
# 2         1       Regular customer         20.0
# 3         1       Regular customer         20.0
# 4         1       Regular customer         20.0
# 5         1       Regular customer         20.0
# 6         1       Regular customer         20.0
# 7         1       Regular customer         20.0
# 8         1       Regular customer         20.0
# 9         1       Regular customer         20.0
# 10       15      Frequent customer          8.0
# 11       15      Frequent customer          8.0
# 12       15      Frequent customer          8.0
# 13       15      Frequent customer          8.0
# 14       15      Frequent customer          8.0
# 15       19      Frequent customer          6.0
# 16       19      Frequent customer          6.0
# 17       19      Frequent customer          6.0
# 18       21      Frequent customer          7.0
# ...

# %%
ords_prods_merge['order_freq_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        22797115
# Regular customer          6921016
# Non-frequent customer     2686728
# Name: order_freq_flag, dtype: int64

# %%
#8
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'opm.pkl'))
